# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
fdist1 = FreqDist(text1)

# %%
fdist1
# Out:
# FreqDist({'[': 3,
#           'Moby': 84,
#           'Dick': 84,
#           'by': 1137,
#           'Herman': 1,
#           'Melville': 1,
#           '1851': 3,
#           ']': 1,
#           'ETYMOLOGY': 1,
#           '.': 6862,
#           '(': 210,
#           'Supplied': 2,
#           'a': 4569,
#           'Late': 1,
#           'Consumptive': 1,
#           'Usher': 2,
#           'to': 4542,
#           'Grammar': 2,
#           'School': 1,
#           ')': 78,
#           'The': 612,
#           'pale': 18,
#           '--': 1070,
#           'threadbare': 1,
#           'in': 3916,
#           'coat': 28,
#           ',': 18713,
#           'heart': 90,
#           'body': 110,
#           'and': 6024,
#           'brain': 37,
#           ';': 4072,
#           'I': 2124,
#           'see': 253,
#           'him': 1058,
#           'now': 646,
#           'He': 230,
#           'was': 1632,
#           'ever': 203,
#           'dusting': 2,
#           'his': 2459,
#           'old': 436,
#           'lexicons': 1,
#           'grammars': 2,
#           'with': 1659,
#           'queer': 44,
#           'handkerchief': 5,
#           'mockingly': 1,
#           'embellished': 3,
#           'all': 1462,
#           'the': 13721,
#           'gay': 13,
#           'flags': 1,
#           'of': 6536,
#           'known': 80,
#           'nations': 12,
#           'world': 173,
#           'loved': 3,
#           'dust': 10,
#           'it': 2209,
#           'somehow': 43,
#           'mildly': 10,
#           'reminded': 4,
#           'mortality': 1,
#           '"': 1478,
#           'While': 30,
#           'you': 841,
#           'take': 118,
#           'hand': 205,
#           'school': 9,
#           'others': 37,
#           'teach': 5,
#           'them': 471,
#           'what': 442,
#           'name': 69,
#           'whale': 906,
#           '-': 2552,
#           'fish': 133,
#           'is': 1695,
#           'be': 1030,
#           'called': 116,
#           'our': 199,
#           'tongue': 11,
#           'leaving': 38,
#           'out': 529,
#           'through': 227,
#           'ignorance': 10,
#           'letter': 12,
#           'H': 2,
#           'which': 640,
#           'almost': 186,
#           'alone': 37,
#           'maketh': 5,
#           'signification': 1,
#           'word': 76,
#           'deliver': 3,
#           'that': 2982,
#           'not': 1103,
#           'true': 73,
#           '."': 489,
#           'HACKLUYT': 1,
#           'WHALE': 38,
#           '...': 11,
#           'Sw': 1,
#           'Dan': 4,
#           'HVAL': 1,
#           'This': 107,
#           'animal': 16,
#           'named': 11,
#           'from': 1052,
#           'roundness': 1,
#           'or': 697,
#           'rolling': 35,
#           'for': 1414,
#           'HVALT': 2,
#           'arched': 10,
#           'vaulted': 2,
#           'WEBSTER': 2,
#           "'": 2684,
#           'S': 63,
#           'DICTIONARY': 3,
#           'It': 310,
#           'more': 501,
#           'immediately': 14,
#           'Dut': 1,
#           'Ger': 1,
#           'WALLEN': 1,
#           'A': 167,
#           'WALW': 1,
#           'IAN': 1,
#           'roll': 16,
#           'wallow': 3,
#           'RICHARDSON': 1,
#           'KETOS': 1,
#           'GREEK': 1,
#           'CETUS': 1,
#           'LATIN': 1,
#           'WHOEL': 1,
#           'ANGLO': 1,
#           'SAXON': 1,
#           'DANISH': 2,
#           'WAL': 1,
#           'DUTCH': 2,
#           'HWAL': 1,
#           'SWEDISH': 1,
#           'ICELANDIC': 1,
#           'ENGLISH': 3,
#           'BALEINE': 1,
#           'FRENCH': 5,
#           'BALLENA': 1,
#           'SPANISH': 4,
#           'PEKEE': 2,
#           'NUEE': 4,
#           'FEGEE': 1,
#           'ERROMANGOAN': 1,
#           'EXTRACTS': 2,
#           'Sub': 7,
#           'Librarian': 1,
#           ').': 15,
#           'will': 379,
#           'seen': 161,
#           'this': 1280,
#           'mere': 42,
#           'painstaking': 1,
#           'burrower': 1,
#           'grub': 1,
#           'worm': 5,
#           'poor': 106,
#           'devil': 51,
#           'appears': 7,
#           'have': 760,
#           'gone': 58,
#           'long': 318,
#           'Vaticans': 1,
#           'street': 10,
#           'stalls': 1,
#           'earth': 46,
#           'picking': 4,
#           'up': 505,
#           'whatever': 44,
#           'random': 5,
#           'allusions': 7,
#           'whales': 237,
#           'he': 1661,
#           'could': 215,
#           'anyways': 2,
#           'find': 55,
#           'any': 320,
#           'book': 38,
#           'whatsoever': 5,
#           'sacred': 7,
#           'profane': 4,
#           'Therefore': 11,
#           'must': 282,
#           'every': 222,
#           'case': 69,
#           'at': 1231,
#           'least': 75,
#           'higgledy': 1,
#           'piggledy': 1,
#           'statements': 4,
#           'however': 80,
#           'authentic': 3,
#           'these': 381,
#           'extracts': 4,
#           'veritable': 4,
#           'gospel': 1,
#           'cetology': 4,
#           'Far': 4,
#           'As': 120,
#           'touching': 45,
#           'ancient': 28,
#           'authors': 3,
#           'generally': 30,
#           'as': 1620,
#           'well': 174,
#           'poets': 3,
#           'here': 272,
#           'appearing': 3,
#           'are': 586,
#           'solely': 6,
#           'valuable': 11,
#           'entertaining': 2,
#           'affording': 2,
#           'glancing': 12,
#           'bird': 17,
#           's': 1739,
#           'eye': 88,
#           'view': 46,
#           'has': 287,
#           'been': 415,
#           'promiscuously': 1,
#           'said': 302,
#           'thought': 149,
#           'fancied': 9,
#           'sung': 2,
#           'Leviathan': 64,
#           'many': 161,
#           'generations': 6,
#           'including': 8,
#           'own': 205,
#           'So': 147,
#           'fare': 10,
#           'thee': 129,
#           'whose': 86,
#           'commentator': 1,
#           'am': 86,
#           'Thou': 39,
#           'belongest': 1,
#           'hopeless': 8,
#           'sallow': 1,
#           'tribe': 9,
#           'no': 484,
#           'wine': 12,
#           'warm': 24,
#           'whom': 43,
#           'even': 181,
#           'Pale': 1,
#           'Sherry': 1,
#           'would': 421,
#           'too': 184,
#           'rosy': 2,
#           'strong': 34,
#           'but': 1113,
#           'one': 889,
#           'sometimes': 81,
#           'loves': 1,
#           'sit': 16,
#           'feel': 56,
#           'devilish': 9,
#           'grow': 24,
#           'convivial': 4,
#           'upon': 538,
#           'tears': 6,
#           'say': 237,
#           'bluntly': 1,
#           'full': 121,
#           'eyes': 155,
#           'empty': 22,
#           'glasses': 10,
#           'altogether': 29,
#           'unpleasant': 3,
#           'sadness': 2,
#           'Give': 15,
#           'Subs': 1,
#           '!': 1269,
#           'For': 197,
#           'how': 187,
#           'much': 218,
#           'pains': 15,
#           'ye': 460,
#           'please': 12,
#           'so': 918,
#           'shall': 84,
#           'go': 182,
#           'thankless': 1,
#           'Would': 11,
#           'clear': 39,
#           'Hampton': 1,
#           'Court': 1,
#           'Tuileries': 3,
#           'But': 705,
#           'gulp': 2,
#           'down': 364,
#           'your': 240,
#           'hie': 1,
#           'aloft': 53,
#           'royal': 29,
#           'mast': 124,
#           'hearts': 29,
#           'friends': 16,
#           'who': 319,
#           'before': 293,
#           'clearing': 4,
#           'seven': 15,
#           'storied': 4,
#           'heavens': 17,
#           'making': 45,
#           'refugees': 1,
#           'pampered': 1,
#           'Gabriel': 20,
#           'Michael': 1,
#           'Raphael': 1,
#           'against': 132,
#           'coming': 50,
#           'Here': 49,
#           'strike': 28,
#           'splintered': 7,
#           'together': 64,
#           'there': 715,
#           'unsplinterable': 1,
#           'And': 369,
#           'God': 132,
#           'created': 6,
#           'great': 293,
#           'GENESIS': 1,
#           'path': 10,
#           'shine': 3,
#           'after': 252,
#           'One': 28,
#           'think': 111,
#           'deep': 69,
#           'hoary': 2,
#           'JOB': 1,
#           'Now': 139,
#           'Lord': 44,
#           'had': 767,
#           'prepared': 12,
#           'swallow': 10,
#           'Jonah': 84,
#           'JONAH': 1,
#           'There': 147,
#           'ships': 87,
#           'thou': 232,
#           'hast': 19,
#           'made': 178,
#           'play': 29,
#           'therein': 5,
#           'PSALMS': 2,
#           'In': 237,
#           'day': 172,
#           'sore': 3,
#           'sword': 23,
#           'punish': 1,
#           'piercing': 4,
#           'serpent': 4,
#           'crooked': 8,
#           'slay': 4,
#           'dragon': 5,
#           'sea': 433,
#           'ISAIAH': 1,
#           'thing': 188,
#           'soever': 1,
#           'besides': 20,
#           'cometh': 1,
#           'within': 78,
#           'chaos': 4,
#           'monster': 49,
#           'mouth': 60,
#           'beast': 4,
#           'boat': 330,
#           'stone': 18,
#           'goes': 54,
#           'incontinently': 1,
#           'foul': 11,
#           'perisheth': 1,
#           'bottomless': 7,
#           'gulf': 4,
#           'paunch': 2,
#           'HOLLAND': 2,
#           'PLUTARCH': 1,
#           'MORALS': 1,
#           'Indian': 57,
#           'Sea': 22,
#           'breedeth': 1,
#           'most': 277,
#           'biggest': 2,
#           'fishes': 3,
#           ':': 162,
#           'among': 158,
#           'Whales': 29,
#           'Whirlpooles': 1,
#           'Balaene': 1,
#           'length': 78,
#           'four': 74,
#           'acres': 3,
#           'arpens': 1,
#           'land': 78,
#           'PLINY': 1,
#           'Scarcely': 1,
#           'we': 413,
#           'proceeded': 6,
#           'two': 285,
#           'days': 80,
#           'on': 1005,
#           'when': 553,
#           'about': 304,
#           'sunrise': 11,
#           'other': 412,
#           'monsters': 9,
#           'appeared': 10,
#           'Among': 8,
#           'former': 20,
#           'monstrous': 10,
#           'size': 12,
#           'came': 130,
#           'towards': 107,
#           'us': 228,
#           'open': 75,
#           'mouthed': 4,
#           'raising': 4,
#           'waves': 48,
#           'sides': 28,
#           'beating': 11,
#           'into': 520,
#           'foam': 19,
#           'TOOKE': 1,
#           'LUCIAN': 1,
#           'THE': 98,
#           'TRUE': 1,
#           'HISTORY': 4,
#           'visited': 7,
#           'country': 25,
#           'also': 88,
#           'catching': 7,
#           'horse': 26,
#           'bones': 48,
#           'very': 311,
#           'value': 6,
#           'their': 612,
#           'teeth': 47,
#           'brought': 38,
#           'some': 578,
#           'king': 25,
#           'best': 62,
#           'were': 680,
#           'catched': 1,
#           'forty': 28,
#           'eight': 24,
#           'fifty': 33,
#           'yards': 27,
#           'six': 31,
#           'killed': 33,
#           'sixty': 17,
#           'OTHER': 2,
#           'OR': 5,
#           'OCTHER': 1,
#           'VERBAL': 1,
#           'NARRATIVE': 4,
#           'TAKEN': 1,
#           'DOWN': 2,
#           'FROM': 10,
#           'HIS': 17,
#           'MOUTH': 1,
#           'BY': 15,
#           'KING': 2,
#           'ALFRED': 1,
#           'D': 23,
#           '890': 1,
#           'whereas': 14,
#           'things': 132,
#           'whether': 76,
#           'vessel': 54,
#           'enter': 9,
#           'dreadful': 6,
#           'lost': 45,
#           'swallowed': 13,
#           'gudgeon': 1,
#           'retires': 1,
#           'security': 3,
#           'sleeps': 7,
#           'MONTAIGNE': 1,
#           'APOLOGY': 1,
#           'FOR': 6,
#           'RAIMOND': 1,
#           'SEBOND': 1,
#           'Let': 38,
#           'fly': 14,
#           'let': 120,
#           'Old': 11,
#           'Nick': 1,
#           'me': 627,
#           'if': 421,
#           'described': 8,
#           'noble': 44,
#           'prophet': 13,
#           'Moses': 2,
#           'life': 162,
#           'patient': 6,
#           'Job': 5,
#           'RABELAIS': 1,
#           'liver': 4,
#           'cartloads': 1,
#           'STOWE': 1,
#           'ANNALS': 1,
#           'seas': 80,
#           'seethe': 3,
#           'like': 624,
#           'boiling': 15,
#           'pan': 3,
#           'LORD': 1,
#           'BACON': 1,
#           'VERSION': 2,
#           'OF': 49,
#           'Touching': 1,
#           'bulk': 32,
#           'ork': 1,
#           'received': 26,
#           'nothing': 102,
#           'certain': 87,
#           'They': 78,
#           'exceeding': 12,
#           'fat': 12,
#           'insomuch': 2,
#           'an': 582,
#           'incredible': 9,
#           'quantity': 13,
#           'oil': 90,
#           'extracted': 5,
#           'IBID': 3,
#           'LIFE': 2,
#           'AND': 37,
#           'DEATH': 1,
#           'sovereignest': 1,
#           'parmacetti': 3,
#           'inward': 4,
#           'bruise': 1,
#           'HENRY': 2,
#           'Very': 11,
#           'HAMLET': 1,
#           'Which': 6,
#           'secure': 12,
#           'skill': 10,
#           'leach': 1,
#           'art': 39,
#           'Mote': 1,
#           'availle': 1,
#           'returne': 1,
#           'againe': 1,
#           'To': 62,
#           'wound': 17,
#           'worker': 1,
#           'lowly': 8,
#           'dart': 24,
#           'Dinting': 1,
#           'breast': 7,
#           'bred': 9,
#           'restless': 4,
#           'paine': 1,
#           'Like': 23,
#           'wounded': 9,
#           'shore': 23,
#           'flies': 7,
#           'thro': 1,
#           'maine': 1,
#           'FAERIE': 1,
#           'QUEEN': 2,
#           'Immense': 1,
#           'motion': 17,
#           'vast': 73,
#           'bodies': 9,
#           'can': 220,
#           'peaceful': 6,
#           'calm': 41,
#           'trouble': 11,
#           'ocean': 71,
#           'til': 1,
#           'boil': 2,
#           'SIR': 4,
#           'WILLIAM': 2,
#           'DAVENANT': 1,
#           'PREFACE': 1,
#           'TO': 21,
#           'GONDIBERT': 1,
#           'What': 174,
#           'spermacetti': 1,
#           'men': 236,
#           'might': 183,
#           'justly': 3,
#           'doubt': 32,
#           'since': 63,
#           'learned': 25,
#           'Hosmannus': 1,
#           'work': 62,
#           'thirty': 26,
#           'years': 94,
#           'saith': 5,
#           'plainly': 39,
#           'Nescio': 1,
#           'quid': 2,
#           'T': 8,
#           'BROWNE': 3,
#           'SPERMA': 2,
#           'CETI': 2,
#           'VIDE': 1,
#           'V': 6,
#           'E': 5,
#           'Spencer': 1,
#           'Talus': 1,
#           'modern': 18,
#           'flail': 1,
#           'threatens': 1,
#           'ruin': 5,
#           'ponderous': 13,
#           'tail': 78,
#           'Their': 6,
#           'fixed': 37,
#           'jav': 1,
#           'lins': 1,
#           'side': 208,
#           'wears': 7,
#           'back': 151,
#           'grove': 3,
#           'pikes': 2,
#           'WALLER': 1,
#           'BATTLE': 2,
#           'SUMMER': 1,
#           'ISLANDS': 1,
#           'By': 52,
#           'Commonwealth': 1,
#           'State': 4,
#           '--(': 4,
#           'Latin': 4,
#           'Civitas': 1,
#           'artificial': 5,
#           'man': 508,
#           'OPENING': 1,
#           'SENTENCE': 1,
#           'HOBBES': 1,
#           'LEVIATHAN': 1,
#           'Silly': 1,
#           'Mansoul': 1,
#           'without': 154,
#           'chewing': 1,
#           'sprat': 1,
#           'PILGRIM': 1,
#           'PROGRESS': 1,
#           'That': 85,
#           'works': 30,
#           'Created': 1,
#           'hugest': 3,
#           'swim': 20,
#           'stream': 11,
#           'PARADISE': 1,
#           'LOST': 1,
#           '---"': 1,
#           'Hugest': 1,
#           'living': 73,
#           'creatures': 34,
#           'Stretched': 1,
#           'promontory': 5,
#           'swims': 8,
#           'seems': 84,
#           'moving': 13,
#           'gills': 4,
#           'Draws': 1,
#           'breath': 18,
#           'spouts': 16,
#           'mighty': 47,
#           'water': 185,
#           'swimming': 29,
#           'FULLLER': 1,
#           'PROFANE': 1,
#           'HOLY': 1,
#           'STATE': 1,
#           'close': 54,
#           'behind': 50,
#           'lie': 26,
#           'huge': 29,
#           'attend': 9,
#           'prey': 14,
#           'give': 71,
#           'chance': 46,
#           'fry': 3,
#           'gaping': 3,
#           'jaws': 30,
#           'mistake': 9,
#           'way': 269,
#           'DRYDEN': 1,
#           'ANNUS': 1,
#           'MIRABILIS': 1,
#           'floating': 24,
#           'stern': 48,
#           'ship': 507,
#           'they': 586,
#           'cut': 50,
#           'off': 217,
#           'head': 335,
#           'tow': 16,
#           'near': 69,
#           'come': 150,
#           'aground': 1,
#           'twelve': 16,
#           'thirteen': 2,
#           'feet': 125,
#           'THOMAS': 3,
#           'EDGE': 1,
#           'TEN': 1,
#           'VOYAGES': 3,
#           'SPITZBERGEN': 1,
#           'IN': 19,
#           'PURCHAS': 1,
#           'saw': 115,
#           'sporting': 4,
#           'wantonness': 1,
#           'fuzzing': 1,
#           'pipes': 8,
#           'vents': 1,
#           'nature': 34,
#           'placed': 36,
#           'shoulders': 13,
#           'HERBERT': 1,
#           'INTO': 1,
#           'ASIA': 1,
#           'AFRICA': 1,
#           'HARRIS': 2,
#           'COLL': 2,
#           'such': 336,
#           'troops': 2,
#           'forced': 18,
#           'proceed': 14,
#           'deal': 12,
#           'caution': 2,
#           'fear': 32,
#           'should': 181,
#           'run': 51,
#           'SCHOUTEN': 1,
#           'SIXTH': 1,
#           'CIRCUMNAVIGATION': 1,
#           'We': 47,
#           'set': 74,
#           'sail': 96,
#           'Elbe': 1,
#           'wind': 67,
#           'N': 2,
#           'Jonas': 3,
#           'Whale': 282,
#           'Some': 38,
#           't': 283,
#           'fable': 5,
#           'frequently': 14,
#           'climb': 4,
#           'masts': 26,
#           'first': 210,
#           'discoverer': 2,
#           'ducat': 1,
#           'told': 45,
#           'taken': 50,
#           'Shetland': 2,
#           'above': 56,
#           'barrel': 5,
#           'herrings': 1,
#           'belly': 9,
#           'harpooneers': 55,
#           'caught': 44,
#           'once': 144,
#           'Spitzbergen': 4,
#           'white': 191,
#           'over': 403,
#           'VOYAGE': 7,
#           'GREENLAND': 1,
#           '1671': 2,
#           'Several': 1,
#           'coast': 40,
#           'Fife': 1,
#           'Anno': 1,
#           '1652': 1,
#           'eighty': 4,
#           'bone': 50,
#           'kind': 27,
#           'informed': 4,
#           '),': 62,
#           'did': 246,
#           'afford': 9,
#           '500': 2,
#           'weight': 17,
#           'baleen': 11,
#           'stand': 83,
#           'gate': 4,
#           'garden': 6,
#           'Pitferren': 1,
#           'SIBBALD': 1,
#           'FIFE': 1,
#           'KINROSS': 1,
#           'Myself': 1,
#           'agreed': 3,
#           'try': 49,
#           'master': 23,
#           'kill': 30,
#           'Sperma': 1,
#           'ceti': 1,
#           'never': 195,
#           'hear': 60,
#           'sort': 152,
#           'fierceness': 1,
#           'swiftness': 6,
#           'RICHARD': 1,
#           'STRAFFORD': 1,
#           'LETTER': 1,
#           'BERMUDAS': 1,
#           'PHIL': 1,
#           'TRANS': 1,
#           '1668': 1,
#           'voice': 46,
#           'obey': 8,
#           'PRIMER': 1,
#           'abundance': 4,
#           'large': 77,
#           'being': 219,
#           'those': 297,
#           'southern': 5,
#           'may': 230,
#           'hundred': 50,
#           'than': 309,
#           'northward': 4,
#           'CAPTAIN': 2,
#           'COWLEY': 1,
#           'ROUND': 2,
#           'GLOBE': 4,
#           '1729': 1,
#           '"...': 1,
#           'frequendy': 1,
#           'attended': 6,
#           'insupportable': 1,
#           'smell': 11,
#           'bring': 18,
#           'disorder': 1,
#           'ULLOA': 1,
#           'SOUTH': 1,
#           'AMERICA': 1,
#           'chosen': 3,
#           'sylphs': 1,
#           'special': 15,
#           'note': 6,
#           'trust': 4,
#           'important': 19,
#           'charge': 10,
#           'petticoat': 1,
#           'Oft': 1,
#           'fold': 6,
#           'fence': 2,
#           'fail': 17,
#           'Tho': 1,
#           'stuffed': 5,
#           'hoops': 11,
#           'armed': 15,
#           'ribs': 20,
#           'RAPE': 1,
#           'LOCK': 1,
#           'If': 60,
#           'compare': 7,
#           'animals': 5,
#           'respect': 16,
#           'magnitude': 21,
#           'abode': 2,
#           'appear': 6,
#           'contemptible': 4,
#           'comparison': 6,
#           'doubtless': 12,
#           'largest': 19,
#           'creation': 7,
#           'GOLDSMITH': 2,
#           'NAT': 1,
#           'HIST': 2,
#           'write': 5,
#           'little': 247,
#           'make': 109,
#           'speak': 47,
#           'wales': 1,
#           'JOHNSON': 1,
#           'afternoon': 10,
#           'supposed': 15,
#           'rock': 14,
#           'found': 115,
#           'dead': 90,
#           'Asiatics': 2,
#           'then': 571,
#           'towing': 14,
#           'ashore': 33,
#           'seemed': 283,
#           'endeavor': 4,
#           'conceal': 2,
#           'themselves': 59,
#           'order': 64,
#           'avoid': 6,
#           'COOK': 1,
#           'larger': 9,
#           'seldom': 24,
#           'venture': 5,
#           'attack': 8,
#           'dread': 12,
#           'afraid': 15,
#           'mention': 15,
#           'names': 12,
#           'carry': 25,
#           'dung': 1,
#           'lime': 1,
#           'juniper': 1,
#           'wood': 34,
#           'articles': 10,
#           'same': 213,
#           'boats': 145,
#           'terrify': 3,
#           'prevent': 6,
#           'approach': 5,
#           'UNO': 1,
#           'VON': 1,
#           'TROIL': 1,
#           'LETTERS': 1,
#           'ON': 11,
#           'BANKS': 1,
#           'SOLANDER': 1,
#           'ICELAND': 2,
#           '1772': 1,
#           'Spermacetti': 2,
#           'Nantuckois': 1,
#           'active': 8,
#           'fierce': 11,
#           'requires': 7,
#           'address': 4,
#           'boldness': 2,
#           'fishermen': 28,
#           'JEFFERSON': 1,
#           'MEMORIAL': 1,
#           'MINISTER': 1,
#           '1778': 2,
#           'pray': 6,
#           'sir': 143,
#           'equal': 14,
#           '?"': 252,
#           'EDMUND': 2,
#           'BURKE': 2,
#           'REFERENCE': 1,
#           'PARLIAMENT': 1,
#           'NANTUCKET': 11,
#           'FISHERY': 2,
#           'Spain': 5,
#           'stranded': 12,
#           'shores': 7,
#           'Europe': 5,
#           'SOMEWHERE': 1,
#           '.)': 22,
#           'tenth': 4,
#           'branch': 4,
#           'ordinary': 19,
#           'revenue': 2,
#           'grounded': 3,
#           'consideration': 8,
#           'guarding': 1,
#           'protecting': 1,
#           'pirates': 9,
#           'robbers': 1,
#           'right': 97,
#           'sturgeon': 3,
#           'either': 39,
#           'thrown': 25,
#           'property': 7,
#           'BLACKSTONE': 1,
#           'Soon': 17,
#           'sport': 3,
#           'death': 71,
#           'crews': 16,
#           'repair': 3,
#           'Rodmond': 1,
#           'unerring': 3,
#           'o': 16,
#           'er': 7,
#           'suspends': 1,
#           'barbed': 6,
#           'steel': 32,
#           'turn': 54,
#           'attends': 1,
#           'FALCONER': 1,
#           'SHIPWRECK': 2,
#           'Bright': 1,
#           'shone': 3,
#           'roofs': 1,
#           'domes': 1,
#           'spires': 6,
#           'rockets': 1,
#           ...})

# %%
print(fdist1)
# Out:
# <FreqDist with 19317 samples and 260819 outcomes>

# %%
fdist1.most_common(25)
# Out:
# [(',', 18713),
#  ('the', 13721),
#  ('.', 6862),
#  ('of', 6536),
#  ('and', 6024),
#  ('a', 4569),
#  ('to', 4542),
#  (';', 4072),
#  ('in', 3916),
#  ('that', 2982),
#  ("'", 2684),
#  ('-', 2552),
#  ('his', 2459),
#  ('it', 2209),
#  ('I', 2124),
#  ('s', 1739),
#  ('is', 1695),
#  ('he', 1661),
#  ('with', 1659),
#  ('was', 1632),
#  ('as', 1620),
#  ('"', 1478),
#  ('all', 1462),
#  ('for', 1414),
#  ('this', 1280)]

# %%
#cummulative freq distribution

fdist1.plot(50, cumulative=True)

# %%
from nltk.probability import ConditionalFreqDist

# %%
cfdist = ConditionalFreqDist((len(word),word) for word in text1)

# %%
cfdist[3] #- three letter words
# Out:
# FreqDist({'!\'"': 1,
#           '!)"': 1,
#           '!--': 141,
#           '"--': 19,
#           "'--": 2,
#           ')--': 4,
#           ',--': 86,
#           '--"': 95,
#           "--'": 9,
#           '--(': 4,
#           '."*': 1,
#           '.\'"': 3,
#           '.--': 45,
#           '...': 11,
#           '000': 20,
#           '100': 1,
#           '101': 1,
#           '102': 1,
#           '103': 1,
#           '104': 1,
#           '105': 1,
#           '106': 1,
#           '107': 1,
#           '108': 1,
#           '109': 1,
#           '110': 1,
#           '111': 1,
#           '112': 1,
#           '113': 1,
#           '114': 1,
#           '115': 1,
#           '116': 1,
#           '117': 1,
#           '118': 1,
#           '119': 1,
#           '120': 1,
#           '121': 1,
#           '122': 1,
#           '123': 1,
#           '124': 1,
#           '125': 1,
#           '126': 1,
#           '127': 1,
#           '128': 1,
#           '129': 1,
#           '130': 1,
#           '131': 1,
#           '132': 1,
#           '133': 1,
#           '134': 1,
#           '135': 1,
#           '144': 1,
#           '150': 1,
#           '180': 2,
#           '1ST': 1,
#           '1st': 1,
#           '2ND': 1,
#           '400': 2,
#           '440': 1,
#           '4TH': 1,
#           '500': 2,
#           '550': 3,
#           '5TH': 1,
#           '800': 3,
#           '890': 1,
#           ':"-': 1,
#           ':--': 29,
#           ';--': 64,
#           '?--': 74,
#           'ALL': 9,
#           'AND': 37,
#           'ANY': 1,
#           'ARE': 1,
#           'Aft': 1,
#           'Ain': 3,
#           'Air': 2,
#           'All': 55,
#           'And': 369,
#           'Any': 6,
#           'Are': 11,
#           'Ark': 2,
#           'Arm': 1,
#           'Art': 2,
#           'Asa': 1,
#           'Aye': 87,
#           'BIT': 1,
#           'Bad': 2,
#           'Bag': 1,
#           'Bay': 4,
#           'Boy': 15,
#           'Bud': 1,
#           'But': 705,
#           'CAP': 1,
#           'Can': 16,
#           'Cap': 1,
#           'Caw': 1,
#           'Cod': 5,
#           'Cut': 3,
#           'DAM': 1,
#           'DEL': 1,
#           'DID': 2,
#           'DON': 1,
#           'Dan': 4,
#           'Dar': 1,
#           'Day': 4,
#           'Del': 1,
#           'Den': 1,
#           'Dey': 1,
#           'Did': 10,
#           'Dog': 2,
#           'Don': 35,
#           'Dry': 1,
#           'Dut': 1,
#           'Ego': 1,
#           'End': 1,
#           'Ere': 13,
#           'FIN': 2,
#           'FOR': 6,
#           'Far': 4,
#           'Fat': 2,
#           'Few': 2,
#           'Fin': 7,
#           'For': 197,
#           'GAM': 3,
#           'Gam': 1,
#           'Gay': 8,
#           'Ger': 1,
#           'Get': 3,
#           'Goa': 1,
#           'God': 132,
#           'Gor': 2,
#           'HAS': 1,
#           'HIM': 6,
#           'HIS': 17,
#           'HOW': 1,
#           'Had': 12,
#           'Hah': 1,
#           'Har': 1,
#           'Has': 4,
#           'Hat': 1,
#           'Hay': 1,
#           'Hem': 2,
#           'Her': 3,
#           'Him': 3,
#           'His': 54,
#           'Hoe': 1,
#           'How': 67,
#           'IAN': 1,
#           'III': 12,
#           'ILE': 1,
#           'INN': 1,
#           'ITS': 1,
#           'Icy': 3,
#           'Ifs': 1,
#           'Inn': 9,
#           'Its': 3,
#           'JOB': 1,
#           'Jew': 1,
#           'Jig': 1,
#           'Job': 5,
#           'Joe': 1,
#           'Joy': 1,
#           'Kee': 2,
#           'Kit': 1,
#           'Koo': 1,
#           'LAY': 7,
#           'LEG': 1,
#           'LIE': 1,
#           'Lad': 1,
#           'Law': 1,
#           'Lay': 4,
#           'Led': 1,
#           'Lee': 1,
#           'Leg': 2,
#           'Leo': 3,
#           'Let': 38,
#           'Lit': 1,
#           'Log': 1,
#           'Low': 4,
#           'MAT': 1,
#           'MEN': 1,
#           'MSS': 1,
#           'Mab': 1,
#           'Mad': 1,
#           'Man': 19,
#           'Mat': 1,
#           'May': 10,
#           'Men': 7,
#           'Met': 1,
#           'Mrs': 13,
#           'NAT': 1,
#           'NEW': 2,
#           'NOT': 1,
#           'Nat': 1,
#           'Nay': 13,
#           'New': 47,
#           'Nod': 1,
#           'Nor': 76,
#           'Not': 47,
#           'Now': 139,
#           'Nun': 1,
#           'Nut': 1,
#           'OFF': 1,
#           'OLD': 3,
#           'ONE': 4,
#           'OUT': 2,
#           'Off': 2,
#           'Oft': 1,
#           'Old': 11,
#           'One': 28,
#           'Our': 8,
#           'Out': 7,
#           'PIP': 6,
#           'Pan': 2,
#           'Pig': 1,
#           'Pip': 68,
#           'Put': 1,
#           'RED': 1,
#           'REV': 1,
#           'Rad': 4,
#           'Ram': 3,
#           'Rat': 1,
#           'Ray': 1,
#           'Red': 3,
#           'Rev': 1,
#           'Rib': 2,
#           'Rig': 5,
#           'Rio': 2,
#           'Rue': 1,
#           'Run': 3,
#           'SHE': 2,
#           'SIR': 4,
#           'SKY': 1,
#           'Sag': 8,
#           'Sal': 3,
#           'Sam': 2,
#           'Saw': 1,
#           'Say': 7,
#           'Sea': 22,
#           'See': 19,
#           'Set': 2,
#           'She': 15,
#           'Sin': 1,
#           'Sir': 28,
#           'Son': 3,
#           'Sow': 1,
#           'Sub': 7,
#           'TEN': 1,
#           'THE': 98,
#           'THY': 1,
#           'TIT': 1,
#           'TOP': 1,
#           'TWO': 6,
#           'Ten': 2,
#           'The': 612,
#           'Tho': 1,
#           'Thy': 7,
#           'Tic': 1,
#           'Tis': 7,
#           'Tit': 2,
#           'Tom': 3,
#           'Too': 1,
#           'Top': 2,
#           'Try': 5,
#           'Tun': 11,
#           'Tut': 1,
#           'Two': 7,
#           'UNO': 1,
#           'VON': 1,
#           'Van': 1,
#           'Von': 1,
#           'WAL': 1,
#           'WAS': 1,
#           'WAY': 1,
#           'WON': 1,
#           'War': 3,
#           'Was': 11,
#           'Way': 1,
#           'Wet': 2,
#           'Who': 44,
#           'Why': 48,
#           'Woe': 6,
#           'Won': 1,
#           'Woo': 1,
#           'XVI': 1,
#           'YOU': 6,
#           'Yea': 5,
#           'Yes': 49,
#           'Yet': 45,
#           'Yon': 1,
#           'You': 47,
#           'act': 30,
#           'add': 6,
#           'ado': 3,
#           'aft': 31,
#           'age': 21,
#           'ago': 36,
#           'aid': 1,
#           'aim': 3,
#           'ain': 19,
#           'air': 141,
#           'alb': 1,
#           'ale': 4,
#           'all': 1462,
#           'and': 6024,
#           'ant': 3,
#           'any': 320,
#           'ape': 2,
#           'apt': 7,
#           'arc': 2,
#           'are': 586,
#           'ark': 6,
#           'arm': 88,
#           'art': 39,
#           'ash': 6,
#           'ask': 10,
#           'ass': 2,
#           'ate': 3,
#           'awe': 14,
#           'axe': 5,
#           'aye': 68,
#           'bad': 15,
#           'bag': 21,
#           'bar': 11,
#           'bat': 1,
#           'bay': 4,
#           'bed': 76,
#           'beg': 3,
#           'bet': 1,
#           'bid': 7,
#           'big': 13,
#           'bit': 27,
#           'boa': 1,
#           'bob': 1,
#           'bow': 44,
#           'box': 18,
#           'boy': 50,
#           'bud': 4,
#           'but': 1113,
#           'buy': 3,
#           'bye': 13,
#           'can': 220,
#           'cap': 7,
#           'car': 1,
#           'cat': 2,
#           'caw': 5,
#           'cob': 1,
#           'cod': 8,
#           'con': 1,
#           'cow': 1,
#           'cry': 39,
#           'cub': 4,
#           'cup': 8,
#           'cut': 50,
#           'dad': 1,
#           'dam': 18,
#           'dan': 3,
#           'dat': 20,
#           'day': 172,
#           'den': 12,
#           'dew': 2,
#           'dey': 6,
#           'did': 246,
#           'die': 30,
#           'dig': 8,
#           'dim': 20,
#           'din': 4,
#           'dip': 5,
#           'dis': 1,
#           'dog': 17,
#           'don': 103,
#           'dry': 14,
#           'due': 6,
#           'dug': 3,
#           'dun': 1,
#           'ear': 12,
#           'eat': 11,
#           'eau': 1,
#           'ebb': 2,
#           'eel': 2,
#           'elm': 1,
#           'end': 99,
#           'ere': 66,
#           'err': 1,
#           'etc': 3,
#           'eve': 4,
#           'eye': 88,
#           'fac': 1,
#           'fan': 5,
#           'far': 161,
#           'fat': 12,
#           'fed': 6,
#           'fee': 1,
#           'few': 92,
#           'fin': 25,
#           'fit': 16,
#           'fix': 1,
#           'fly': 14,
#           'foe': 14,
#           'fog': 3,
#           'for': 1414,
#           'fro': 17,
#           'fry': 3,
#           'fun': 6,
#           'fur': 1,
#           'gag': 2,
#           'gam': 3,
#           'gap': 1,
#           'gas': 2,
#           'gay': 13,
#           'gem': 1,
#           'get': 92,
#           'gin': 4,
#           'god': 20,
#           'gor': 1,
#           'got': 46,
#           'gun': 7,
#           'had': 767,
#           'hag': 1,
#           'ham': 1,
#           'hap': 3,
#           'has': 287,
#           'hat': 39,
#           'hav': 5,
#           'hay': 4,
#           'hee': 3,
#           'hem': 4,
#           'hen': 3,
#           'her': 329,
#           'hey': 8,
#           'hid': 1,
#           'hie': 1,
#           'him': 1058,
#           'hip': 3,
#           'his': 2459,
#           'hit': 14,
#           'hob': 1,
#           'hoe': 2,
#           'hoo': 1,
#           'hop': 3,
#           'hot': 23,
#           'how': 187,
#           'hue': 14,
#           'hug': 3,
#           'hum': 9,
#           'ice': 27,
#           'icy': 4,
#           'ill': 19,
#           'imp': 1,
#           'ing': 1,
#           'ink': 1,
#           'inn': 6,
#           'ire': 1,
#           'isn': 1,
#           'its': 372,
#           'jam': 2,
#           'jar': 3,
#           'jav': 1,
#           'jaw': 58,
#           'jet': 32,
#           'jib': 5,
#           'jig': 3,
#           'job': 9,
#           'jot': 6,
#           'joy': 16,
#           'jub': 2,
#           'keg': 1,
#           'key': 12,
#           'kin': 2,
#           'lad': 23,
#           'lap': 1,
#           'lar': 1,
#           'law': 20,
#           'lay': 67,
#           'lbs': 7,
#           'led': 9,
#           'lee': 19,
#           'leg': 86,
#           'let': 120,
#           'lid': 9,
#           'lie': 26,
#           'lip': 10,
#           'lit': 8,
#           'liv': 1,
#           'log': 21,
#           'loo': 1,
#           'lot': 5,
#           'low': 35,
#           'lug': 1,
#           'lye': 2,
#           'mad': 36,
#           'man': 508,
#           'map': 3,
#           'mat': 11,
#           'maw': 3,
#           'may': 230,
#           'men': 236,
#           'met': 18,
#           'mid': 12,
#           'mob': 5,
#           'mop': 1,
#           'mow': 1,
#           'mud': 1,
#           'mug': 1,
#           'mum': 1,
#           'nap': 4,
#           'nay': 16,
#           'net': 5,
#           'new': 50,
#           'nod': 2,
#           'non': 2,
#           'nor': 80,
#           'not': 1103,
#           'now': 646,
#           'nut': 3,
#           'oak': 5,
#           'oar': 28,
#           'odd': 10,
#           'off': 217,
#           'oft': 2,
#           'oil': 90,
#           'old': 436,
#           'oly': 1,
#           'one': 889,
#           'ork': 1,
#           'our': 199,
#           'out': 529,
#           'owe': 1,
#           'own': 205,
#           'pan': 3,
#           'paw': 3,
#           'pay': 18,
#           'pea': 2,
#           'peg': 2,
#           'pen': 6,
#           'per': 2,
#           'pie': 2,
#           'pig': 5,
#           'pin': 6,
#           'pit': 7,
#           'ply': 2,
#           'pod': 4,
#           'pop': 1,
#           'pot': 10,
#           'pox': 1,
#           'pre': 6,
#           'pry': 4,
#           'put': 72,
#           'rag': 2,
#           'ram': 4,
#           'ran': 24,
#           'rap': 3,
#           'rat': 2,
#           'raw': 1,
#           'ray': 2,
#           'red': 36,
#           'reg': 1,
#           'ren': 1,
#           'rex': 1,
#           'rib': 11,
#           'rid': 4,
#           'rig': 4,
#           'rim': 2,
#           'rip': 1,
#           'rob': 1,
#           'rod': 15,
#           'rot': 3,
#           'row': 17,
#           'rub': 1,
#           'rug': 1,
#           'rum': 3,
#           'run': 51,
#           'sad': 9,
#           'sap': 3,
#           'sat': 45,
#           'saw': 115,
#           'say': 237,
#           'sea': 433,
#           'sed': 1,
#           'see': 253,
#           'set': 74,
#           'sex': 1,
#           'she': 103,
#           'shy': 1,
#           'sin': 7,
#           'sir': 143,
#           'sit': 16,
#           'six': 31,
#           'sky': 35,
#           'sly': 1,
#           'sob': 3,
#           'sod': 1,
#           'sog': 1,
#           'son': 17,
#           'sou': 2,
#           'sow': 2,
#           'spy': 2,
#           'sum': 9,
#           'sun': 102,
#           'sup': 1,
#           'tap': 5,
#           'tar': 9,
#           'tat': 1,
#           'tea': 5,
#           'tee': 1,
#           'ten': 45,
#           'the': 13721,
#           'tho': 1,
#           'thy': 105,
#           'tie': 1,
#           'til': 1,
#           'tin': 2,
#           'tip': 3,
#           'tis': 19,
#           'toe': 2,
#           'ton': 3,
#           'too': 184,
#           'top': 68,
#           'tow': 16,
#           'toy': 2,
#           'tri': 2,
#           'try': 49,
#           'tub': 14,
#           'tug': 1,
#           'tun': 3,
#           'two': 285,
#           'urn': 1,
#           'use': 36,
#           'van': 4,
#           'vat': 1,
#           'via': 1,
#           'vow': 4,
#           'vum': 1,
#           'wad': 4,
#           'wag': 2,
#           'wan': 1,
#           'war': 23,
#           'was': 1632,
#           'wat': 1,
#           'wax': 4,
#           'way': 269,
#           'wee': 1,
#           'wet': 9,
#           'who': 319,
#           'why': 71,
#           'wid': 2,
#           'wit': 2,
#           'woe': 25,
#           'won': 30,
#           'yaw': 2,
#           'yea': 9,
#           'yes': 26,
#           'yet': 300,
#           'yon': 9,
#           'you': 841,
#           'zag': 1,
#           'zay': 1,
#           'zig': 1})

# %%
cfdist[5] #- Five letter words
# Out:
# FreqDist({'Usher': 2,
#           'heart': 90,
#           'brain': 37,
#           'queer': 44,
#           'flags': 1,
#           'known': 80,
#           'world': 173,
#           'loved': 3,
#           'While': 30,
#           'teach': 5,
#           'whale': 906,
#           'which': 640,
#           'alone': 37,
#           'WHALE': 38,
#           'named': 11,
#           'HVALT': 2,
#           'KETOS': 1,
#           'GREEK': 1,
#           'CETUS': 1,
#           'LATIN': 1,
#           'WHOEL': 1,
#           'ANGLO': 1,
#           'SAXON': 1,
#           'DUTCH': 2,
#           'PEKEE': 2,
#           'FEGEE': 1,
#           'devil': 51,
#           'earth': 46,
#           'could': 215,
#           'every': 222,
#           'least': 75,
#           'these': 381,
#           'poets': 3,
#           'whose': 86,
#           'tribe': 9,
#           'would': 421,
#           'loves': 1,
#           'tears': 6,
#           'empty': 22,
#           'pains': 15,
#           'shall': 84,
#           'Would': 11,
#           'clear': 39,
#           'Court': 1,
#           'aloft': 53,
#           'royal': 29,
#           'seven': 15,
#           'there': 715,
#           'great': 293,
#           'shine': 3,
#           'after': 252,
#           'think': 111,
#           'hoary': 2,
#           'Jonah': 84,
#           'JONAH': 1,
#           'There': 147,
#           'ships': 87,
#           'sword': 23,
#           'thing': 188,
#           'chaos': 4,
#           'mouth': 60,
#           'beast': 4,
#           'stone': 18,
#           'among': 158,
#           'acres': 3,
#           'PLINY': 1,
#           'about': 304,
#           'other': 412,
#           'Among': 8,
#           'waves': 48,
#           'sides': 28,
#           'TOOKE': 1,
#           'horse': 26,
#           'bones': 48,
#           'value': 6,
#           'their': 612,
#           'teeth': 47,
#           'forty': 28,
#           'eight': 24,
#           'fifty': 33,
#           'yards': 27,
#           'sixty': 17,
#           'OTHER': 2,
#           'TAKEN': 1,
#           'MOUTH': 1,
#           'enter': 9,
#           'noble': 44,
#           'Moses': 2,
#           'liver': 4,
#           'STOWE': 1,
#           'BACON': 1,
#           'DEATH': 1,
#           'HENRY': 2,
#           'Which': 6,
#           'skill': 10,
#           'leach': 1,
#           'wound': 17,
#           'lowly': 8,
#           'paine': 1,
#           'shore': 23,
#           'flies': 7,
#           'maine': 1,
#           'QUEEN': 2,
#           'ocean': 71,
#           'might': 183,
#           'doubt': 32,
#           'since': 63,
#           'years': 94,
#           'saith': 5,
#           'Talus': 1,
#           'flail': 1,
#           'Their': 6,
#           'fixed': 37,
#           'wears': 7,
#           'grove': 3,
#           'pikes': 2,
#           'State': 4,
#           'Latin': 4,
#           'Silly': 1,
#           'sprat': 1,
#           'works': 30,
#           'swims': 8,
#           'seems': 84,
#           'gills': 4,
#           'Draws': 1,
#           'water': 185,
#           'STATE': 1,
#           'close': 54,
#           'ANNUS': 1,
#           'stern': 48,
#           'pipes': 8,
#           'vents': 1,
#           'SIXTH': 1,
#           'Jonas': 3,
#           'Whale': 282,
#           'fable': 5,
#           'climb': 4,
#           'masts': 26,
#           'first': 210,
#           'ducat': 1,
#           'taken': 50,
#           'above': 56,
#           'belly': 9,
#           'white': 191,
#           'coast': 40,
#           'stand': 83,
#           'never': 195,
#           'TRANS': 1,
#           'voice': 46,
#           'large': 77,
#           'being': 219,
#           'those': 297,
#           'ROUND': 2,
#           'GLOBE': 4,
#           'smell': 11,
#           'bring': 18,
#           'ULLOA': 1,
#           'SOUTH': 1,
#           'trust': 4,
#           'fence': 2,
#           'hoops': 11,
#           'armed': 15,
#           'abode': 2,
#           'write': 5,
#           'speak': 47,
#           'wales': 1,
#           'found': 115,
#           'order': 64,
#           'avoid': 6,
#           'dread': 12,
#           'names': 12,
#           'carry': 25,
#           'boats': 145,
#           'TROIL': 1,
#           'BANKS': 1,
#           'equal': 14,
#           'BURKE': 2,
#           'Spain': 5,
#           'tenth': 4,
#           'right': 97,
#           'sport': 3,
#           'death': 71,
#           'crews': 16,
#           'steel': 32,
#           'shone': 3,
#           'roofs': 1,
#           'domes': 1,
#           'vault': 3,
#           'VISIT': 1,
#           'blood': 59,
#           'SMALL': 1,
#           'SIZED': 1,
#           'aorta': 1,
#           'PALEY': 1,
#           'BARON': 1,
#           'south': 7,
#           'dived': 11,
#           'chace': 1,
#           'paint': 5,
#           'waste': 3,
#           'front': 25,
#           'horns': 8,
#           'fangs': 3,
#           'WORLD': 1,
#           'FLOOD': 1,
#           'Paean': 1,
#           'finny': 2,
#           'round': 242,
#           'Polar': 11,
#           'green': 50,
#           'where': 190,
#           'grand': 43,
#           'bread': 16,
#           'built': 8,
#           'Susan': 1,
#           'TWICE': 1,
#           'TALES': 2,
#           'Right': 51,
#           'threw': 10,
#           'PILOT': 1,
#           'stage': 10,
#           'Chace': 3,
#           'stove': 22,
#           'ESSEX': 1,
#           'WHICH': 2,
#           'LARGE': 2,
#           'SPERM': 5,
#           'OCEAN': 2,
#           'CHACE': 1,
#           'FIRST': 1,
#           'night': 147,
#           'OAKES': 1,
#           'SMITH': 1,
#           'miles': 31,
#           'three': 237,
#           'fresh': 32,
#           'Sperm': 135,
#           'rolls': 14,
#           'rears': 1,
#           'snaps': 1,
#           'point': 70,
#           'BEALE': 1,
#           'blows': 23,
#           'Where': 29,
#           'Three': 8,
#           'Raise': 1,
#           'wheel': 6,
#           'shoal': 8,
#           'bowes': 1,
#           'hands': 123,
#           'Globe': 1,
#           'board': 73,
#           'Being': 5,
#           'lance': 45,
#           'onset': 6,
#           'noise': 12,
#           'Dutch': 24,
#           'Ocean': 8,
#           'India': 5,
#           'These': 21,
#           'bound': 28,
#           'again': 254,
#           'clews': 1,
#           'North': 8,
#           'under': 117,
#           'short': 59,
#           'heads': 85,
#           'while': 216,
#           'throw': 13,
#           'Terra': 1,
#           'Fuego': 1,
#           'beech': 2,
#           'Stern': 5,
#           'lives': 22,
#           'storm': 32,
#           'giant': 2,
#           'money': 12,
#           'purse': 7,
#           'hypos': 1,
#           'upper': 30,
#           'moral': 3,
#           'isles': 14,
#           'coral': 7,
#           'reefs': 1,
#           'hours': 42,
#           'sight': 105,
#           'China': 8,
#           'still': 299,
#           'desks': 1,
#           'limit': 5,
#           'shady': 1,
#           'lanes': 1,
#           'north': 7,
#           'unite': 6,
#           'lakes': 3,
#           'magic': 9,
#           'going': 83,
#           'knows': 28,
#           'chief': 30,
#           'trees': 14,
#           'trunk': 17,
#           'sleep': 44,
#           'smoke': 30,
#           'winds': 20,
#           'spurs': 2,
#           'sighs': 2,
#           'visit': 10,
#           'Tiger': 1,
#           'charm': 7,
#           'Water': 5,
#           'sadly': 12,
#           'Beach': 2,
#           'crazy': 14,
#           'deity': 1,
#           'story': 47,
#           'grasp': 5,
#           'image': 11,
#           'habit': 3,
#           'begin': 12,
#           'lungs': 16,
#           'needs': 20,
#           'enjoy': 5,
#           'glory': 17,
#           'toils': 1,
#           'quite': 41,
#           'brigs': 3,
#           'fowls': 11,
#           'river': 6,
#           'plumb': 1,
#           'sense': 14,
#           'hunks': 3,
#           'broom': 3,
#           'sweep': 13,
#           'decks': 21,
#           'slave': 8,
#           'thump': 5,
#           'punch': 6,
#           'Again': 9,
#           'penny': 4,
#           'heard': 110,
#           'BEING': 1,
#           'maxim': 3,
#           'smelt': 3,
#           'Fates': 6,
#           'drawn': 25,
#           'brief': 10,
#           'GRAND': 2,
#           'parts': 41,
#           'jolly': 22,
#           'Chief': 6,
#           'quick': 31,
#           'terms': 12,
#           'place': 116,
#           'flood': 14,
#           'gates': 2,
#           'swung': 20,
#           'shirt': 8,
#           'offer': 8,
#           'young': 76,
#           'doing': 15,
#           'craft': 54,
#           'sally': 2,
#           'chase': 56,
#           'sloop': 4,
#           'forth': 52,
#           'laden': 5,
#           'stood': 89,
#           'gloom': 12,
#           'lodge': 3,
#           'price': 1,
#           'steps': 5,
#           'paced': 9,
#           'Sword': 2,
#           'house': 43,
#           'frost': 8,
#           'thick': 27,
#           'weary': 16,
#           'soles': 1,
#           'boots': 14,
#           'watch': 52,
#           'broad': 56,
#           'glare': 3,
#           'smoky': 3,
#           'light': 77,
#           'meant': 14,
#           'porch': 2,
#           'ashes': 12,
#           'Black': 7,
#           'black': 83,
#           'faces': 15,
#           'Angel': 1,
#           'negro': 22,
#           'docks': 5,
#           'misty': 3,
#           'spray': 16,
#           'words': 28,
#           'Peter': 10,
#           'quiet': 12,
#           'ruins': 2,
#           'burnt': 7,
#           'creak': 1,
#           'cheap': 2,
#           'gable': 4,
#           'ended': 7,
#           'sharp': 42,
#           'bleak': 3,
#           'worse': 21,
#           'doors': 8,
#           'glass': 19,
#           'wight': 5,
#           'Death': 18,
#           'chips': 5,
#           'Dives': 3,
#           'Orion': 1,
#           'coals': 5,
#           'along': 110,
#           'fiery': 23,
#           'tepid': 2,
#           'entry': 8,
#           'study': 7,
#           'lines': 37,
#           'yeast': 2,
#           'boggy': 1,
#           'soggy': 1,
#           'truly': 19,
#           'drive': 17,
#           'froze': 1,
#           'heath': 1,
#           'scene': 27,
#           'midst': 10,
#           'plain': 37,
#           'faint': 11,
#           'final': 29,
#           'based': 3,
#           'clean': 15,
#           'array': 3,
#           'clubs': 1,
#           'ivory': 54,
#           'knots': 3,
#           'human': 35,
#           'grass': 15,
#           'mower': 2,
#           'gazed': 10,
#           'Mixed': 1,
#           'rusty': 3,
#           'Swain': 1,
#           'flung': 11,
#           'Javan': 2,
#           'slain': 12,
#           'dusky': 5,
#           'times': 111,
#           'beams': 5,
#           'fancy': 26,
#           'shelf': 5,
#           'table': 35,
#           'cases': 25,
#           'dusty': 3,
#           'nooks': 3,
#           'angle': 7,
#           'coach': 4,
#           'swift': 24,
#           'sells': 2,
#           'pours': 2,
#           'avast': 9,
#           'added': 25,
#           'haint': 1,
#           'liked': 2,
#           'ready': 40,
#           'bench': 13,
#           'knife': 29,
#           'space': 15,
#           'sheet': 7,
#           'funny': 7,
#           'likes': 3,
#           'afore': 5,
#           'began': 53,
#           'spend': 9,
#           'cried': 155,
#           'coats': 3,
#           'stiff': 9,
#           'bears': 11,
#           'mixed': 11,
#           'pitch': 19,
#           'swore': 7,
#           'colds': 1,
#           'newly': 6,
#           'aloof': 1,
#           'spoil': 4,
#           'sober': 7,
#           'whole': 136,
#           'chest': 26,
#           'brawn': 2,
#           'brown': 7,
#           'Ridge': 2,
#           'clock': 16,
#           'comes': 52,
#           'Kings': 4,
#           'cover': 11,
#           'linen': 4,
#           'ought': 8,
#           'sorry': 6,
#           'spare': 21,
#           'rough': 4,
#           'plane': 8,
#           'wrist': 6,
#           'eider': 1,
#           'plank': 17,
#           'chair': 8,
#           'small': 125,
#           'fetch': 9,
#           'steal': 2,
#           'march': 4,
#           'knock': 3,
#           'Still': 13,
#           'early': 11,
#           'airth': 2,
#           'keeps': 8,
#           'stick': 5,
#           'guess': 18,
#           'BROWN': 1,
#           'hears': 5,
#           'break': 23,
#           'broke': 12,
#           'Broke': 2,
#           'BROKE': 1,
#           'Hecla': 1,
#           'delay': 3,
#           'beget': 9,
#           'unsay': 1,
#           'stark': 9,
#           'purty': 1,
#           'cause': 22,
#           'folks': 3,
#           'slept': 4,
#           'floor': 20,
#           'Arter': 1,
#           'jiffy': 1,
#           'walls': 11,
#           'hooks': 5,
#           'tried': 15,
#           'edges': 3,
#           'South': 21,
#           'guise': 3,
#           'rainy': 1,
#           'stuck': 9,
#           'hurry': 9,
#           'After': 17,
#           'heavy': 37,
#           'cords': 7,
#           'spoke': 15,
#           'fight': 19,
#           'truth': 30,
#           'lying': 16,
#           'ideas': 6,
#           'scalp': 1,
#           'skull': 25,
#           'Years': 2,
#           'frogs': 1,
#           'palms': 15,
#           'Going': 6,
#           'grego': 3,
#           'hunch': 3,
#           'Congo': 2,
#           'ebony': 3,
#           'jambs': 1,
#           'sooty': 3,
#           'First': 24,
#           'takes': 25,
#           'flame': 16,
#           'blaze': 2,
#           'hasty': 2,
#           'badly': 4,
#           'moved': 14,
#           'pagan': 15,
#           'spell': 10,
#           'spent': 9,
#           'fatal': 17,
#           'grunt': 2,
#           'debel': 1,
#           'Watch': 5,
#           'Speak': 5,
#           'thank': 9,
#           'civil': 2,
#           'stash': 3,
#           'touch': 30,
#           'parti': 1,
#           'shade': 7,
#           'owing': 22,
#           'strip': 10,
#           'quilt': 2,
#           'awoke': 2,
#           'child': 18,
#           'dream': 10,
#           'caper': 1,
#           'crawl': 6,
#           'third': 29,
#           'ached': 1,
#           'sound': 41,
#           'awake': 9,
#           'outer': 20,
#           'shock': 15,
#           'frame': 4,
#           'piled': 14,
#           'awful': 18,
#           'fears': 6,
#           'weeks': 9,
#           'often': 68,
#           'alive': 25,
#           'clasp': 1,
#           'twain': 6,
#           'rouse': 1,
#           'snore': 1,
#           'aside': 24,
#           'faced': 5,
#           'style': 5,
#           'shook': 13,
#           'staff': 6,
#           'signs': 13,
#           'dress': 4,
#           'leave': 18,
#           'worth': 14,
#           'minus': 3,
#           'crush': 4,
#           'piece': 16,
#           'razor': 2,
#           'slips': 2,
#           'stock': 10,
#           'whets': 1,
#           'using': 11,
#           'pilot': 25,
#           'baton': 1,
#           'laugh': 17,
#           'stuff': 19,
#           'allow': 3,
#           'mates': 39,
#           'bosky': 1,
#           'gowns': 1,
#           'cheek': 7,
#           'musky': 3,
#           'looks': 27,
#           'satin': 3,
#           'tints': 2,
#           'Andes': 7,
#           'slope': 2,
#           'Mungo': 2,
#           'Green': 4,
#           'timid': 8,
#           'beats': 3,
#           'flesh': 23,
#           'makes': 39,
#           'stare': 3,
#           'cloak': 1,
#           'dandy': 3,
#           'joins': 1,
#           'burst': 21,
#           'tract': 1,
#           'spite': 16,
#           'parks': 1,
#           'lofty': 21,
#           'brave': 18,
#           'sweet': 23,
#           'cones': 1,
#           'rocks': 15,
#           'women': 11,
#           'bloom': 4,
#           'roses': 4,
#           'match': 9,
#           'Salem': 1,
#           'girls': 8,
#           'sands': 2,
#           'moody': 13,
#           'sunny': 5,
#           'sleet': 7,
#           'cloth': 8,
#           'wives': 5,
#           'apart': 15,
#           'grief': 7,
#           'quote': 1,
#           'CANNY': 1,
#           'GLEIG': 1,
#           'ELIZA': 1,
#           'towed': 8,
#           'HARDY': 1,
#           'Japan': 10,
#           'WIDOW': 1,
#           'bleed': 1,
#           'voids': 2,
#           'Faith': 4,
#           'grave': 17,
#           'tales': 4,
#           'Sands': 1,
#           'bliss': 3,
#           'rumor': 1,
#           'feeds': 4,
#           'tombs': 1,
#           'vital': 10,
#           'murky': 2,
#           'thine': 17,
#           'merry': 11,
#           'stave': 9,
#           'youth': 9,
#           'hardy': 8,
#           'acted': 3,
#           'ropes': 13,
#           'means': 44,
#           'taste': 11,
#           'knobs': 1,
#           'joint': 7,
#           'fully': 16,
#           'snowy': 8,
#           'angel': 6,
#           'plate': 7,
#           'azure': 6,
#           'trace': 5,
#           'bluff': 4,
#           'Bible': 10,
#           'leads': 3,
#           'wrath': 6,
#           'brunt': 1,
#           'shoes': 7,
#           'tones': 5,
#           'bowed': 10,
#           'speed': 12,
#           'borne': 9,
#           'Awful': 1,
#           'mercy': 9,
#           'power': 37,
#           'pause': 7,
#           'verse': 1,
#           'yarns': 5,
#           'cable': 7,
#           'kelpy': 1,
#           'slime': 2,
#           'hence': 23,
#           'reign': 3,
#           'Joppa': 8,
#           'seeks': 6,
#           'lurks': 9,
#           'Cadiz': 4,
#           'Jaffa': 2,
#           'scorn': 5,
#           'cross': 17,
#           'wrong': 8,
#           'wharf': 11,
#           'finds': 9,
#           'items': 5,
#           'cargo': 3,
#           'cabin': 79,
#           'goods': 1,
#           'tries': 1,
#           'smile': 5,
#           'widow': 7,
#           'Harry': 3,
#           'Sodom': 1,
#           'spile': 2,
#           'coins': 5,
#           'reads': 2,
#           'crowd': 9,
#           'cries': 16,
#           'turns': 34,
#           'darts': 4,
#           "?'--'": 1,
#           'calls': 12,
#           'scent': 1,
#           'crime': 2,
#           'judge': 4,
#           'usual': 9,
#           'paves': 1,
#           'rings': 7,
#           'Point': 2,
#           'state': 23,
#           'cells': 3,
#           'berth': 10,
#           'gasps': 2,
#           'feels': 16,
#           'wards': 3,
#           'bales': 2,
#           'false': 7,
#           'hangs': 6,
#           'burns': 4,
#           'Roman': 15,
#           'giddy': 1,
#           'until': 8,
#           'whirl': 2,
#           'drags': 4,
#           'casts': 3,
#           'boxes': 5,
#           'heeds': 2,
#           'arise': 2,
#           'leaps': 4,
#           'shows': 7,
#           'steep': 5,
#           'eager': 13,
#           'howls': 1,
#           'drops': 6,
#           'bolts': 7,
#           'learn': 8,
#           'pangs': 2,
#           'shown': 6,
#           'model': 4,
#           'swell': 11,
#           'spake': 3,
#           'press': 3,
#           'raise': 8,
#           'gulfs': 1,
#           'weeds': 2,
#           'reach': 14,
#           'Truth': 6,
#           'appal': 3,
#           'Pilot': 2,
#           'truck': 7,
#           'proud': 8,
#           'gives': 18,
#           'kills': 1,
#           'pluck': 2,
#           'robes': 5,
#           'shake': 15,
#           'Thine': 1,
#           'Bosom': 1,
#           'pages': 4,
#           'count': 2,
#           'Pagan': 8,
#           'freer': 2,
#           'busts': 1,
#           'brows': 2,
#           'woman': 10,
#           'glows': 1,
#           'bland': 2,
#           'hints': 10,
#           'pouch': 2,
#           'puffs': 5,
#           'waist': 11,
#           'bosom': 6,
#           'rules': 3,
#           'apply': 1,
#           'paper': 6,
#           'twice': 10,
#           'peace': 7,
#           'souls': 22,
#           'knees': 8,
#           'noses': 4,
#           'crown': 17,
#           'spark': 1,
#           'prove': 13,
#           'clout': 2,
#           'goats': 1,
#           'uncle': 2,
#           'aunts': 1,
#           'veins': 4,
#           'lands': 7,
#           'vowed': 3,
#           'Alone': 2,
#           'canoe': 11,
#           'flash': 8,
#           'naked': 12,
#           'Wales': 1,
#           'wages': 3,
#           'lived': 13,
#           'Hence': 9,
#           'asked': 14,
#           'nonce': 2,
#           'share': 4,
#           'dying': 13,
#           'block': 11,
#           'barbs': 12,
#           'forms': 12,
#           'feast': 6,
#           'bride': 4,
#           'Grace': 4,
#           'grace': 4,
#           'ducks': 1,
#           'Giver': 1,
#           'opens': 2,
#           'hills': 10,
#           'casks': 20,
#           'fires': 4,
#           'start': 28,
#           'waxed': 1,
#           'marks': 15,
#           'heels': 2,
#           'hoofs': 3,
#           'drink': 16,
#           'filed': 3,
#           'blast': 10,
#           'canes': 2,
#           'Hallo': 1,
#           'gaunt': 5,
#           'swept': 9,
#           'panic': 8,
#           'lower': 57,
#           'lasso': 1,
#           'saved': 6,
#           'voted': 1,
#           'trump': 3,
#           'clove': 1,
#           'medal': 1,
#           'brine': 4,
#           'elbow': 1,
#           'beach': 16,
#           'plant': 3,
#           'blade': 8,
#           'oasis': 1,
#           'utter': 6,
#           'clams': 3,
#           'backs': 12,
#           'olden': 1,
#           'eagle': 4,
#           'crabs': 3,
#           'grown': 20,
#           'waded': 1,
#           'Texas': 2,
#           'globe': 19,
#           'forts': 1,
#           'riots': 2,
#           'THERE': 7,
#           'cocks': 3,
#           'hides': 3,
#           'folds': 6,
#           'wings': 7,
#           'furls': 1,
#           'sails': 45,
#           'herds': 11,
#           'Hosea': 5,
#           'given': 36,
#           'asses': 1,
#           'sawed': 1,
#           'vague': 10,
#           'crick': 1,
#           'brisk': 4,
#           'Shirt': 1,
#           'steam': 6,
#           'belie': 2,
#           'juicy': 3,
#           'hazel': 2,
#           'fishy': 4,
#           'paved': 3,
#           'books': 16,
#           'shark': 27,
#           'rooms': 5,
#           'plans': 1,
#           'fleet': 10,
#           'vigor': 1,
#           'XXXIX': 1,
#           'Devil': 4,
#           'DEVIL': 1,
#           'Medes': 1,
#           'pryed': 1,
#           'aught': 11,
#           'junks': 2,
#           'calms': 3,
#           'alike': 10,
#           'Egypt': 3,
#           'kings': 14,
#           'Peleg': 74,
#           'sperm': 104,
#           'thews': 2,
#           'Those': 9,
#           'holds': 7,
#           'steed': 4,
#           'shape': 17,
#           'slabs': 4,
#           'laced': 1,
#           'loose': 21,
#           'hairy': 3,
#           'waved': 5,
#           'oaken': 5,
#           'stout': 13,
#           'gales': 3,
#           'scowl': 2,
#           'lingo': 2,
#           'Didst': 1,
#           'didst': 8,
#           'Young': 4,
#           'below': 46,
#           'ports': 7,
#           'yours': 8,
#           'alien': 5,
#           'idiom': 1,
#           'blend': 4,
#           'force': 12,
#           'birth': 10,
#           'phase': 1,
#           'cared': 3,
#           'sworn': 3,
#           'pious': 9,
#           'owner': 6,
#           'swear': 13,
#           'cruel': 8,
#           'spike': 3,
#           'exact': 8,
#           'beard': 5,
#           'tails': 6,
#           'wants': 8,
#           'aware': 5,
#           'steer': 9,
#           '275th': 4,
#           'lucky': 7,
#           'Cloud': 1,
#           '200th': 1,
#           'crony': 1,
#           ...})
